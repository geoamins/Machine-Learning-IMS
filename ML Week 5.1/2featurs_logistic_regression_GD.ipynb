# %%
# Logistic Regression with 2 Features (from scratch) + Decision Boundary
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# Dataset (2 Features)
# -----------------------------
# Example: [Study Hours, Sleep Hours]
X = np.array([
    [1, 2],
    [2, 1],
    [3, 3],
    [4, 5],
    [5, 4]
])

y = np.array([0, 0, 0, 1, 1]).reshape(-1, 1)

# %%
# Initialize parameters
# -----------------------------
m, n = X.shape
w = np.zeros((n, 1))
b = 0
alpha = 0.1

# %%
# Sigmoid function
# -----------------------------
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
# Compute initial loss (before training)
z_initial = np.dot(X, w) + b
y_hat_initial = sigmoid(z_initial)
initial_loss = -(1/m) * np.sum(y * np.log(y_hat_initial) + (1 - y) * np.log(1 - y_hat_initial))
print("Initial Weights:", w.flatten())
print("Initial Bias:", b)
print("Initial Loss:", initial_loss)
# Out:
# Initial Weights: [0.66763282 0.66763282]
# Initial Bias: -4.395402776214578
# Initial Loss: 0.21109665727969573

# %%
# Training loop
# -----------------------------
iterations = 500

for i in range(iterations):
    z = np.dot(X, w) + b
    y_hat = sigmoid(z)
        
    loss = -(1/m) * np.sum(y * np.log(y_hat) + (1 - y) * np.log(1 - y_hat))
    
    dw = (1/m) * np.dot(X.T, (y_hat - y))
    db = (1/m) * np.sum(y_hat - y)
    
    w = w - alpha * dw
    b = b - alpha * db

# %%
print("Final Weights:\n", w)
print("Final Bias:\n", b)
print("Final Loss:", loss)
# Out:
# Final Weights:
#  [[0.66763282]
#  [0.66763282]]
# Final Bias:
#  -4.395402776214578
# Final Loss: 0.21133419669571119
